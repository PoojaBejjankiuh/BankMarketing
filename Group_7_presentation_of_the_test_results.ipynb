# %% [markdown]
# # Group 7
# ## B. Pooja sree prasanna (2311609)
# ## Pavan Kalyan Yakkali (2249432)
# ## Teja Akula (1862814)
# ## Prajith Sai Macha (2313014)

# %% [markdown]
# # Bank Marketing Data Analysis

# %% [markdown]
# # step 6
# Perform visualization of your model performances, insights etc using apt metrics and charts (ex: MSE bar plots of all the models to identify best models)

# %% [markdown]
# # Step 1
# ## By using  5 modeling techniques:  ́
# *  Linear regression/classification
# *  KNN
# * Random Forest
# * SVM with linear kernel and SVM with nonlinear kernel
# * Decision Tree
#
# # logistic regression
# * Accuracy1 =  0.908587068080739
# * Precision1 =  0.9102227140683359
# * Recall1 =  0.9054630521535709
# * F1Score1 =  0.9078366445916114
#
# # KNN
# * Accuracy2 =  0.9208347588094423
# * Precision2 =  0.9148560564910375
# * Recall2 =  0.9270675657079951
# * F1Score2 =  0.9209213314195885
#
# # Random Forest
# * Accuracy3 =  0.9482723229558673
# * Precision3 =  0.940110855752332
# * Recall3 =  0.9569285812577405
# * F1Score3 =  0.9484451718494272
#
# # SVM
# * Accuracy4 =  0.9261033185083818
# * Precision4 =  0.9219751739189742
# * Recall4 =  0.9300949497729462
# * F1Score4 =  0.9260172626387175
#
# # SVM using Linear
# * Accuracy41 =  0.8725
# * Precision41 =  0.8341232227488151
# * Recall41 =  0.9166666666666666
# * F1Score41 =  0.8734491315136476
#
# # Desicion TRee
#
# * Accuracy6 =  0.9284296955183031
# * Precision6 =  0.9239471173504157
# * Recall6 =  0.93284711710472
# * F1Score6 =  0.9283757874554918
#
# # By observing the Model performance The Best Model is Ramdom Forest

# %%
# logistic regression
Accuracy1 =  0.908587068080739
Precision1 =  0.9102227140683359
Recall1 =  0.9054630521535709
F1Score1 =  0.9078366445916114

# KNN
Accuracy2 =  0.9208347588094423
Precision2 =  0.9148560564910375
Recall2 =  0.9270675657079951
F1Score2 =  0.9209213314195885

# Random Forest
Accuracy3 =  0.9482723229558673
Precision3 =  0.940110855752332
Recall3 =  0.9569285812577405
F1Score3 =  0.9484451718494272

# SVM
Accuracy4 =  0.9261033185083818
Precision4 =  0.9219751739189742
Recall4 =  0.9300949497729462
F1Score4 =  0.9260172626387175

# SVM using Linear
Accuracy41 =  0.8725
Precision41 =  0.8341232227488151
Recall41 =  0.9166666666666666
F1Score41 =  0.8734491315136476

# Desicion TRee

Accuracy6 =  0.9284296955183031
Precision6 =  0.9239471173504157
Recall6 =  0.93284711710472
F1Score6 =  0.9283757874554918

# %%
import matplotlib.pyplot as plt
datadf={"logistic regression":Accuracy1,"knn":Accuracy2,"random forest":Accuracy3,"svc using RBF":Accuracy4,"SVM using Linear":Accuracy41,"Decision Tree":Accuracy6}

categories = list(datadf.keys())
values1 = list(datadf.values())
values = [round(value, 4) for value in values1]
plt.figure(figsize=(8, 6))
bars = plt.bar(categories, values,)
# Adding value labels on top of each bar
for bar in bars:
    plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height(), str(bar.get_height()), ha='center', va='bottom')

plt.xlabel('Categories')
plt.ylabel('Values')
plt.title('Model Performance Comparison')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Step 2  Selecting Perform Variable Selection. Choose one of the following techniques and explain why you selected that one.
# *  Lasso: https://en.wikipedia.org/wiki/Lasso_(statistics))
# * KNN
# * Correlation

# %% [markdown]
# ## Lasso was choosen for feature selection
#
# Lasso is chosen for variable selection because it selects the most relevant featuress by shrinking less important coefficients to zero.
# Lasso is the good choice  while handling multicollinearity and working well with large datasets.
#
# ## con's of other two mentioned methods are
# KNN:
# * Computationally expensive with large datasets.
#
# Correlation:
# * Only measures linear relationships, ignores non-linear associations.

# %%
print("Selected Columns: {}".format(feature_subset))
# Out:
# Selected Columns: ['loan' 'emp.var.rate' 'euribor3m' 'job_blue-collar' 'job_entrepreneur'
#  'job_housemaid' 'job_management' 'job_retired' 'job_self-employed'
#  'job_services' 'job_student' 'job_technician' 'job_unemployed'
#  'marital_married' 'marital_single' 'education_basic.6y'
#  'education_basic.9y' 'education_high.school' 'education_illiterate'
#  'education_professional.course' 'education_university.degree'
#  'poutcome_nonexistent' 'poutcome_success' 'y']

# %% [markdown]
# # Step 3:  Perform model structure selection to select the hyperparameters of your models after step 2 feature selection(Using grid search or Random search or any other method). Perform visualization of your model performances using apt metrics and charts (ex: MSE bar plots models before and afteroptimizing hyperparameters).
#
# ## After appling Feature selection Random Forest is giving the Hifhest performance

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # step 4  Use the best model from step 1 and step 3 and perform another variable selection using a Bi- directional elimination as a wrapper method
# ![image.png](data:image/png;base64,...)
#
# The Accuracy Obtained is
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # The best method in step 1 and step 3 is Random Forest after applying the Bi Directional Method the Accuracy is 94.6 %

# %% [markdown]
# # Step 5 After feature selection step 2 also build (Based on the models compatibility with the data i.e classification or regression problem) (also write a 3 lines on what you understand about these models you are free to use online resources but please cite them):
# * XGBoost
# * Extreme Machine Learning Model
# * A basic deep learning model with two layers
# * An Ensemble model containing the top 3 models overall

# %% [markdown]
# ## XGBoost model
# * XGBoost Accuracy: 94.46%
#
# ## Extreme Machine learning model
# * Extreme Machine learning model Accuracy: 93.09%
#
# ## Deep Learning Model
# * Deep Learning Model Accuracy: 50.27%
#
#
# ## An Ensemble model containing the top 3 models overall
# ```
# random forest Training accuracy: 99.98%
# random forest Test accuracy: 94.84%
#
# knn Training accuracy: 93.35%
# knn Test accuracy: 92.00%
#
# decision tree Training accuracy: 99.98%
# decision tree Test accuracy: 92.82%
#
# Voting Classfier Training accuracy: 99.98%
# Voting Classfier Test accuracy: 94.58%
# ```

# %% [markdown]
# ### For the Bank Marketing Data analysis after applying Many models, We can observe Random Forest is working Well.
# # The Best Performing Model is RANDOM FOREST
